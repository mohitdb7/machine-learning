# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv("Delhi+Delights+Data.csv")
ds.shape
# Out:
# (30, 3)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Average Delivery Rating (a1)   30 non-null     float64
#  1   Average Orders per month (a2)  30 non-null     int64
#  2   "Delighted Members" Purchase   30 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 852.0+ bytes

# %%
ds_a1_l = ds[ds['Average Delivery Rating (a1)'] < 3]
ds_a1_r = ds[ds['Average Delivery Rating (a1)'] >= 3]

ds_a1_l.shape, ds_a1_r.shape, len(ds_a1_r)
# Out:
# ((15, 3), (15, 3), 15)

# %%
(len(ds_a1_l[ds_a1_l['"Delighted Members" Purchase'] == 'Yes']) / len(ds_a1_l))**2 + (len(ds_a1_l[ds_a1_l['"Delighted Members" Purchase'] != 'Yes']) / len(ds_a1_l))**2
# Out:
# 0.5022222222222222

# %%
1 - ((len(ds_a1_l[ds_a1_l['"Delighted Members" Purchase'] == 'Yes']) / len(ds_a1_l))**2 + (len(ds_a1_l[ds_a1_l['"Delighted Members" Purchase'] != 'Yes']) / len(ds_a1_l))**2)
# Out:
# 0.49777777777777776

# %%
(len(ds_a1_r[ds_a1_r['"Delighted Members" Purchase'] == 'Yes'])), len(ds_a1_r[ds_a1_r['"Delighted Members" Purchase'] != 'Yes'])
# Out:
# (8, 7)

# %%
1 - ((len(ds_a1_r[ds_a1_r['"Delighted Members" Purchase'] == 'Yes']) / len(ds_a1_r))**2 + (len(ds_a1_r[ds_a1_r['"Delighted Members" Purchase'] != 'Yes']) / len(ds_a1_r))**2)
# Out:
# 0.49777777777777776

# %%
ds_a2_l = ds[ds['Average Orders per month (a2)'] < 20]
ds_a2_r = ds[ds['Average Orders per month (a2)'] >= 20]

# %%
1 - ((len(ds_a2_l[ds_a2_l['"Delighted Members" Purchase'] == 'Yes']) / len(ds_a2_l))**2 + (len(ds_a2_l[ds_a2_l['"Delighted Members" Purchase'] != 'Yes']) / len(ds_a2_l))**2)
# Out:
# 0.4012345679012346

# %%
1 - ((len(ds_a2_r[ds_a2_r['"Delighted Members" Purchase'] == 'Yes']) / len(ds_a2_r))**2 + (len(ds_a2_r[ds_a2_r['"Delighted Members" Purchase'] != 'Yes']) / len(ds_a2_r))**2)
# Out:
# 0.2777777777777777

# %%
len(ds[ds['"Delighted Members" Purchase'] == 'Yes']) / len(ds), len(ds[ds['"Delighted Members" Purchase'] != 'Yes']) / len(ds)
# Out:
# (0.5, 0.5)

# %%
0.49 + 0.49
# Out:
# 0.98

# %%
0.40 + 0.28
# Out:
# 0.68
